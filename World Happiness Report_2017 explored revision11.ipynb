# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mplt
# %matplotlib inline
from IPython.display import Image

# %%
#df = pd.read_csv('Human_Development_Index.csv')
#print(df)

# %%
df = pd.read_csv('2017.csv')


pd.DataFrame(df)
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# 5                 Netherlands               6            7.377      7.427426
# 6                      Canada               7            7.316      7.384403
# 7                 New Zealand               8            7.314      7.379510
# 8                      Sweden               9            7.284      7.344095
# 9                   Australia              10            7.284      7.356651
# 10                     Israel              11            7.213      7.279853
# ...

# %%
df = df.drop(columns=['Happiness.Rank'])

# %%
plt.rcParams['figure.figsize'] = (10,3)
#df.set_index("Country", drop=True,inplace=True)
df['Happiness.Score'].head(50).plot(kind='bar')
#plt.rcParams['figure.figsize'] = (15,8)
plt.ylabel('Level of Perceived Happiness')
plt.title('50 Happiest Countries')
# Out:
# Text(0.5,1,'50 Happiest Countries')

# %%
plt.rcParams['figure.figsize'] = (20,8)
df[:10].plot.bar()

plt.title('Top 10 Happiest Countries: All Variables')
#plt.rcParams['figure.figsize'] = (10,6)
#df.'Happiness.Rank'.head(20).plot(kind='bar')
#plt.ylabel('Top 20 Happiest Countries')
# Out:
# Text(0.5,1,'Top 10 Happiest Countries: All Variables')

# %%
plt.rcParams['figure.figsize'] = (20,8)
#df[145:].plot.bar()
df.iloc[145:, ].plot.bar()
plt.title('10 Least Happy Countries: All Variables')
# Out:
# Text(0.5,1,'10 Least Happy Countries: All Variables')

# %% [markdown]
# Essential Questions
#
# 1.Is there a correlation between relative afluence (as indicated by GDP per capita) and the devaluing of the family?
#
# GDP per Capita is ranked slightly higher than family for four of the 10 countries that recieved the highest happiness scores.
# 2. Why is this?  What does it mean for the future of family?
#
# At the same time, as shown on the graph below, only one of countries that scored among the 10 lowest for happiness valued family significantly more than they valued the GDP per 2. capita. (Likewise, the two countries from this group with the lowest dystopia residuals valued.)
# 3.Why is this?

# %% [markdown]
# Question for Mike:
#
# Given the size of this data set, and the type of information it offers, can Bayes' Theorem be used drawing only from the data set's information?

# %%
ax1 = plt.scatter(x=df['Happiness.Score'], y=df['Economy..GDP.per.Capita.'])
ax2 = plt.scatter(x=df['Happiness.Score'], y=df['Family'])
plt.ylabel('Happiness Score', size='10')
plt.legend()
plt.show()

# %%
#df.set_index("Country",drop=True,inplace=True)
plt.rcParams['figure.figsize'] = (10,2)
df.Family.head(20).plot(kind='bar', color='c')
plt.ylabel('Family Size')
plt.title('20 Happiest Countries: Value Placed on Family')

#df.Family.value_counts().head(20).plot(kind='bar')
# Out:
# Text(0.5,1,'20 Happiest Countries: Value Placed on Family')

# %%
#df.set_index("Country",drop=True,inplace=True)
plt.rcParams['figure.figsize'] = (10,2)
df.Family.tail(20).plot(kind='bar', color='g')
plt.ylabel('Family Size')
plt.title('20 Least Happy Counrties: Value Placed on Family')
# Out:
# Text(0.5,1,'20 Least Happy Counrties: Value Placed on Family')

# %%
#purchases.iloc[1:3, 1]

plot = df.iloc[0:9, 3].plot.pie(figsize=(5,5))
plt.title('10 Happiest Countries: Gross Domestic Product Per Capita')
plt.ylabel('')
plt.show()

print('Mean:')
print(df.iloc[0:9, 3].sum() / 10)

print('GDP per Country:')
print(df.iloc[0:9, 3])
#Use a loc statement to slice and select, instead of the above location.  
#First part specifies rows, second part specifies column desired.  
#Revisit slicing, collecting, ad grouping, from the curriculum.
#Undo setting country as index.
#Change x axis labels to country.
# Out:
# Mean:
# 6.621104797393085
# GDP per Country:
# 0    7.479556
# 1    7.462272
# 2    7.385970
# 3    7.426227
# 4    7.410458
# 5    7.326574
# 6    7.247597
# 7    7.248490
# 8    7.223905
# Name: Whisker.low, dtype: float64

# %%
plot= df.iloc[145:, 3].plot.pie(figsize=(5,5))
plt.title('10 Least Happy Countries: Gross Domestic Product Per Capita')
plt.ylabel('')
plt.show()

print('Mean:')
print(df.iloc[145:, 3].sum() / 10)


print('GDP per Country:')
print(df.iloc[145:, 3])
# Out:
# Mean:
# 3.233978492230176
# GDP per Country:
# 145    3.493250
# 146    3.456462
# 147    3.412244
# 148    3.429572
# 149    3.395962
# 150    3.398970
# 151    3.260331
# 152    3.236570
# 153    2.735310
# 154    2.521116
# Name: Whisker.low, dtype: float64

# %%
df.plot(subplots=True, figsize=(10, 10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a45f6f860>,
# ...
#       dtype=object)

# %% [markdown]
# Observation:
# Generosity is valued almost as high in the least happy and poorest countries as it is in the wealthest and happiest nations.

# %%
#plt.rcParams['figure.figsize'] = (10,2)
#health = df.HealthLifeExpectancy.head(20).plot(kind='hist')


health = df.iloc[:20, 5]
#binomial_two_sample1000 = binomial_two[0:1000] 

plt.hist(health)


# Add a vertical line at the mean.
#plt.axvline(rand1.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(health.mean(), color='r', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean.
#plt.axvline(rand1.mean() + rand1.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(health.mean() + health.std(), color='r', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean.
#plt.axvline(rand1.mean()-rand1.std(), color='b', linestyle='dashed', linewidth=2) 
plt.axvline(health.mean() - health.std(), color='r', linestyle='dashed', linewidth=2)


plt.ylabel('Number of Countries')
plt.xlabel('Value Level')
plt.title('20 Happiest Counrties: Value Placed on Health and Longevity')
plt.show()
print('Mean:')
print(health.mean())
print('Standard Deviation:')
print(health.std())
# Out:
# Mean:
# 1.4801378548145296
# Standard Deviation:
# 0.07348842767134071

# %%
#plt.rcParams['figure.figsize'] = (10,2)
#health = df.HealthLifeExpectancy.head(20).plot(kind='hist')
health_unhappy = df.iloc[145:, 5]
#binomial_two_sample1000 = binomial_two[0:1000] 

plt.hist(health_unhappy)


# Add a vertical line at the mean.
#plt.axvline(rand1.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(health_unhappy.mean(), color='r', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean.
#plt.axvline(rand1.mean() + rand1.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(health_unhappy.mean() + health_unhappy.std(), color='r', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean.
#plt.axvline(rand1.mean()-rand1.std(), color='b', linestyle='dashed', linewidth=2) 
plt.axvline(health_unhappy.mean() - health_unhappy.std(), color='r', linestyle='dashed', linewidth=2)


plt.ylabel('Number of Countries')
plt.xlabel('Value Level')
plt.title('20 Least Happy Counrties: Value Placed on Health and Longevity')
plt.show()
print('Mean:')
print(health_unhappy.mean())
print('Standard Deviation:')
print(health_unhappy.std())
# Out:
# Mean:
# 0.6645543545484544
# Standard Deviation:
# 0.3209407485371495

# %% [markdown]
# #Question for Mike:Why isn't the x axis using the age values from the data frame?

# %% [markdown]
# Of the top and bottom 20 countries respectively, which countries have the longest life expectancy? How does this correspond to their relative levels of happyiess amont their top and bottom range peer countries?

# %%
generosity = df.iloc[0:19, 7]
#binomial_two_sample1000 = binomial_two[0:1000] 

plt.hist(generosity)


# Add a vertical line at the mean.
#plt.axvline(rand1.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(generosity.mean(), color='r', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean.
#plt.axvline(rand1.mean() + rand1.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(generosity.mean() + generosity.std(), color='r', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean.
#plt.axvline(rand1.mean()-rand1.std(), color='b', linestyle='dashed', linewidth=2) 
plt.axvline(generosity.mean() - generosity.std(), color='r', linestyle='dashed', linewidth=2)


plt.ylabel('Number of Countries')
plt.xlabel('Level of Generosity')
plt.title('20 Happiest Counrties: Generosity')
plt.show()
print('Mean:')
print(generosity.mean())
print('Standard Deviation:')
print(generosity.std())
# Out:
# Mean:
# 0.5785015648917147
# Standard Deviation:
# 0.056505755841231575

# %%
generosity_tail = df.iloc[145:, 7]
#binomial_two_sample1000 = binomial_two[0:1000] 

plt.hist(generosity_tail)


# Add a vertical line at the mean.
#plt.axvline(rand1.mean(), color='b', linestyle='solid', linewidth=2)
plt.axvline(generosity_tail.mean(), color='r', linestyle='solid', linewidth=2)

# Add a vertical line at one standard deviation above the mean.
#plt.axvline(rand1.mean() + rand1.std(), color='b', linestyle='dashed', linewidth=2)
plt.axvline(generosity_tail.mean() + generosity_tail.std(), color='r', linestyle='dashed', linewidth=2)

# Add a vertical line at one standard deviation below the mean.
#plt.axvline(rand1.mean()-rand1.std(), color='b', linestyle='dashed', linewidth=2) 
plt.axvline(generosity_tail.mean() - generosity_tail.std(), color='r', linestyle='dashed', linewidth=2)


plt.ylabel('Number of Countries')
plt.xlabel('10 Least Happy Counrties: Value Placed on Generosity')
plt.show()
print('Mean:')
print(generosity_tail.mean())
print('Standard Deviation:')
print(generosity_tail.std())
# Out:
# Mean:
# 0.2842564865946771
# Standard Deviation:
# 0.1588631559263388

# %% [markdown]
# Of the top and bottom 20 countries respectively, which countries are the most generous? How does this correspond to their relative levels of happiness amont their top
# and bottom range peer countries? Note: Generosity levels between top and bottom are not far apart.  This raises an interesting question.  Why?)
#
# This is an exploratory capston.  Raise questions by analyzing the data.  We are allowed to speculate using the data.  Start by creating a scatter plot that showes each variable in relation to the happiness score.
#
# x axis = generosity
# y axis = happiness
# index = country

# %%
plt.scatter(x=df['Generosity'], y=df['Happiness.Score'])
plt.ylabel('Happiness.Score')
plt.xlabel('Value Placed on Generosity')
plt.show()

# %%
#Which countries value generosity the most?

top_generosity = df.loc[lambda df: df['Generosity'] > .5, :]
top_generosity.sort_values(by=['Generosity'], ascending=False)

# %% [markdown]
# Analysis of Top 5 Generosity Valuing Countries
#
# Essential Question 1:
#
# Why do these contries self-identify as valuing generosity so highly?  What aspects of Austronesian culture influence cultural attitudes toward enerosity?
# Possible answers: Austronesian cultural values (except one outlier), poor economy
#
# Essential Question 2:  Do Austronesian cultures have something to the West about valuing generosity?
#
# Essential Question 3: Is heighly valuing generosity a function of living in want (i.e. living in poverty)? If so, to what extent?
#
# Essential Question 4: Does the actual amount given, relative to income, per capita (with ethnic wage disparities factored in) out stripe the combined median giving levels of the other countries?  ...or, is it easier to value generosity, when one does not have much to give, but would hope to be a recepient?  (To Do: For an partial answer to this, check top five generosity valuing countries against five countris with t he lowest per capita GDP.)
#
#
# __________________________________________________
# Observations
#
# 1. Commonalities
#
# Culure -
# Austronesian Origin (4 of 5)
# Four of the top five generosity valuing countries are Austronesian, or featuring a large Austronesian minority. The outlier, Malta, is an island nation located of the soutern most tip of Sicily.  It is an Arabic-Italian cultural blended, featuring a semetic language with strong Italian influences.
#
# Cultutrally Non-Western (3 of 5) / (heavy non-Wetern cultural presence/impact 2 of 5)
# The countries ore either cultually non-Western, or like and New Zealand, and Malta respecively, have a strong (per capita and cultural) indegenous or semetic presence.
#
# Geography -
# East Asian (3 of 5)
# Myanmar, Indonesia, and Thailand are East Asian countries.  While New Zealand is not considered East Asian, a large percentage of its population is Maori, a people group that shares a common ancestral, cultural and linguistic heritage, Austroneaian, with its East Asian ancestors.
#
# Economy -
# According to "The World Factbook" Myanmar, Indonesia, Thailand, and Malta, are not is considerd developed nations--a title closely linked to a countries per capita gross domestic product.  While other sources, such as the International Monetary Fund, may currently classify Malta as a "developed" nation. (Source: Wikipedia."The World Factbook list of developed countries," https://en.wikipedia.org/wiki/The_World_Factbook_list_of_developed_countries)
#
# When the 26% of of New Zealand's population tha the not European is considered, the economic trend aligns much more closely with at of nations that are not considered developed. "Even after removing the effects of age structure on the ethnicity data, it is evident there was a large difference in the median net wealth of European people compared with other ethnic groups. The median net wealth of European people was $114,000, more than three times that of the Asian population ($32,000), five times that of Māori ($23,000), and nine times greater than Pacific people ($12,000)" Source: Stats NZ. http://archive.stats.govt.nz/browse_for_stats/people_and_communities/Net%20worth/ethnicity.aspx
#
#
# 2. Outliers
#
# Geographic -
#
# Malta
# In regard to the aforementioned cultural dynamic, Malta, which is located off the coast of Italy, between the European and African continents is the only outlier with respect to the five countries that self identify as valuing generosity.  The Maltese may identify culturally as Arabic, Italian, or a mixture of the two.
#
# Malta joined the European Union in 2004. "Maltese is the only semetic language to be officially recogniced in the European Union" (Source: Wikipedia. https://en.wikipedia.org/wiki/Malta).  However, Maltese is not recognized as an Arabic dialect due to the heavy influence of Italian on the language.
#
#
# Monetary -
#
# European New Zealander
# As the aforepresented statistics show, New Zeal can only be thought of an an economic outlier if only its European citizens are counted, and the profound economic desparity between that group and all other citizens is ignored. Even so, it should be noted that New Zealand is classified as a developed nation in The World Book of Facts, a publication whose classificatons of developed nations is used as an appendix to the United States' CIA Handbook. (Source: Wikipedia."The World Factbook list of developed countries," https://en.wikipedia.org/wiki/The_World_Factbook_list_of_developed_countries)
#
#
# *Since its addtion to the European Union, Malta has recently be reclassifed by some sources as a developed nation. Source: Wikipedia. https://en.wikipedia.org/wiki/Malta)
#
# Happiness Score -
#
# Myanmar
# Myanmar scored significantly lower than the other for countries in terms of Happiness, though it scored the highest in terms of valuing generosity.  Perhaps the main reason for this that it is the only country, of the five that is currently at war. "The Karen conflict is an armed conflict in Kayin State, Myanmar (formerly known as Karen State, Burma). The conflict has been described as one of the world's "longest running civil wars". Karen nationalists have been fighting for an independent state known as Kawthoolei since 1949" Source: Wikipedia. https://en.wikipedia.org/wiki/Karen_conflict
#
# __________________________________________________
# Patterns:
#
# Inverse correlation between Per Capita Gross Domestic Product and Value Placed on generosity, with the exception of Malta.
#
# Inverse correlation between Happiness Score and the valued placed on generosity, with Malta slightly exceedng the trend, in favor of happiness.
#
#
# __________________________________________________
# Questions For Futher Study:
# 1. Why are four of the top five generosity valuing countries Austronesian, or featuring a large Austronesian minority? Are there partricular features of Austronesian cultural beliefs, cultural development, ideas and or workings of economy and trade, that lend themselves to valuing generosity?
#
# 2. Why does the outlier, Malta, value generosity so highly?
#
# 3. Are their other correlations between these five countries that can be discovered by analyzing the data set at hand?

# %%
lowest_generosity = df.loc[lambda df: df['Generosity'] < .045, :]
lowest_generosity.sort_values(by=['Generosity'], ascending=False)

# %% [markdown]
# Commonalities Among 5 Countries That Value Generosity Least
#
# All of them eared a happiness scored of less than 75%, relative to all other countries.
#
# Happiness Score -
#
# Less than 75% for all each of the five countries
# Median Happiness Score:
# Mode: 5.2

# %%
lowest_generosity_happiness_scores = [df.loc[lambda df: df['Generosity'] < .045, :]]

# %%
#Embed a map showing the location and proximity of the countries listed 
#directly above.

#Image("img/picture.png")
#filename = 'myanmar_indo_thai_nzealand_map.jpg'

#img = Image.open(filename)

# %%
y=df['Generosity']
x=df['Happiness.Score']

plt.plot(x, y)
y=df['Health..Life.Expectancy.']
x=df['Happiness.Score']
df['Happiness.Score']
plt.plot(x,y)
plt.legend()
plt.ylabel('Happiness Score')
# Out:
# Text(0,0.5,'Happiness Score')

# %% [markdown]
# Question for Mike: How do I get preceeding visual to display, even if it is not the last line of code in a cell?

# %%
df.sort_values(by=['Generosity'], ascending=False)
df

# %%
plt.scatter(x=df['Health..Life.Expectancy.'], y=df['Happiness.Score'], color='g')
plt.xlabel('Value Placed on Health and Life Expectency')
plt.ylabel('Happiness.Score')
plt.show()

# %%
#Which countries value health and longevity the most?

top_health_valuers = df.loc[lambda df: df['Health..Life.Expectancy.'] > .85, :]

top_health_valuers.sort_values(by=['Health..Life.Expectancy.'], ascending=False)
# Out:
#                     Country  Happiness.Score  Whisker.high  Whisker.low  \
# 25                Singapore            6.572      6.636723     6.507277
# 70  Hong Kong S.A.R., China            5.472      5.549594     5.394406
# 50                    Japan            5.920      5.990719     5.849281
# 54              South Korea            5.838      5.922559     5.753441
# 33                    Spain            6.403      6.471055     6.334945
# 3               Switzerland            7.494      7.561772     7.426227
# 47                    Italy            5.964      6.042737     5.885264
#
#     Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 25                  1.692278  1.353814                  0.949492  0.549841
# 70                  1.551675  1.262791                  0.943062  0.490969
# 50                  1.416915  1.436338                  0.913476  0.505626
# 54                  1.401678  1.128274                  0.900214  0.257922
# ...

# %% [markdown]
# The countries that value health the most are industrialized nations in Asia, with competetive world economies.

# %%
#ax = df.plot.scatter(x=df['Generosity'], y=df['Happiness.Score'], color='DarkBlue', label='Group 1')

#df.plot.scatter(x=df['Family'], y=df['Health..Life.Expectancy.'], color='DarkGreen', label='Group 2', ax=ax)



ax1 = plt.scatter(x=df['Happiness.Score'], y=df['Generosity'])
ax2 = plt.scatter(x=df['Happiness.Score'], y=df['Health..Life.Expectancy.'])
plt.ylabel('Happiness Score')
plt.legend()
plt.show()

# %% [markdown]
# Essential Question:
# First: Before pursuing the question below, make sure that the Happiness Score, is a statement of the value the culture places on happiness, not a score assigned to them.
# Why do humans value happiness significantly more than they value family, health and longevity, and generosity?
